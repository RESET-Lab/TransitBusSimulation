# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)

#from IPython.core.debugger import Tracer
#Tracer()()

# %%
from fastsim import simdrive, vehicle, cycle

# %% [markdown]
# # Q: What does the vehicle data structure look like?

# %%
# Vehicle 22 is a Tesla
veh = vehicle.Vehicle(22)
veh_jit = veh.get_numba_veh()

print('Vehicle Name: ', veh.Scenario_name)

print('Full Vehicle dictionary:\n')
pp.pprint(veh.__dict__)
# Out:
# Vehicle Name:  2016 TESLA Model S60 2WD
# Full Vehicle dictionary:
#
# {   'MaxRoadwayChgKw': array([0., 0., 0., 0., 0., 0.]),
#     'Scenario_name': '2016 TESLA Model S60 2WD',
#     'Selection': 22,
#     'altEff': 1,
#     'auxKw': 0.25,
#     'cargoKg': 136,
#     'chargingOn': False,
#     'chgEff': 0.86,
#     'compMassMultiplier': 1.4,
#     'dragCoef': 0.3,
#     'driveAxleWeightFrac': 0.59,
#     'essBaseKg': 75,
#     'essChgToFcMaxEffPerc': 0.0,
#     'essDischgToFcMaxEffPerc': 0,
#     'essKgPerKwh': 8.0,
#     'essLifeCoefA': 110,
#     'essLifeCoefB': -0.6811,
#     'essMassKg': 944.9999999999999,
#     'essRoundTripEff': 0.97,
#     'essToFuelOkError': 0.005,
#     'fcAbsEffImpr': 0,
#     'fcEffArray': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...
